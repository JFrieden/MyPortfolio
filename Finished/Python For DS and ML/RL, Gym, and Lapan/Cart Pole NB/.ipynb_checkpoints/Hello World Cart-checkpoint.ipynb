# %%
from ipywidgets import Checkbox
from IPython.display import display

checkbox = Checkbox(value = False, description = 'Train New CartPole Agent?')
display(checkbox)

NEW_TRAINING = checkbox.value
# Out:
# Checkbox(value=False, description='Train New CartPole Agent?')

# %%
if NEW_TRAINING:
    print("Run All will Train a new agent")
else:
    print("Run All will load the saved model")
# Out:
# Run All will load the saved model

# %% [markdown]
# # Cart World
#
# From OpenAI's "Gym" library, Cart World has become a defacto "Hello, World!" of RL. The environment is relatively simple: a size 4 vector of 32-bit floats encapsulates the x coordinate of the pole's CoM, its speed, its angle to the cart, and its angular velocity.
#
# ![image.png](attachment:image.png)
#
# The environment simulates some base-level physics for the pole and cart, such that the pole will tip over unless the cart is moved to compensate for its motion, similar to trying to balance a pole upright on one's hand. The environment is configured to treat a fully-tipped-over pole as a terminal state.
#
# The action-space is even more simple. In each time step, the cart can be instructed to move left or right.
#
# Positive reward is given for each time-step during which the pole is not fully tipped over.

# %% [markdown]
# ### Setting up Cart World
# We initialize the `CartPole-v1` Environment, reset it in accordance with best practices, and do some preliminary exploration of its attributes and functions.

# %%
import gym

Env = gym.make("CartPole-v1")
observation_1 = Env.reset()

#Show the action and observation-space properties
print(f"Number and type of actions: {Env.action_space}")
print(f"Observation Space type and size: {Env.observation_space}")
# Out:
# Number and type of actions: Discrete(2)
# Observation Space type and size: Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
# Actions: Env.step(action)
# We instruct the cart to go left, and receive a 5Tuple:
#   1. an observation from our new state
#   2. a reward (+1 for the pole not falling)
#   3. a "terminal state?" boolean (false, the pole hasn't fallen)
#   4. a "truncated?" boolean that indicates if our episode has
#      been ended by a non-terminal state end-condition/constraint.
#   5. extra_info. An often blank dict

print(Env.step(0))
# Out:
# (array([-0.01851783, -0.18180752,  0.01116593,  0.3421307 ], dtype=float32), 1.0, False, False, {})

# %% [markdown]
# ### The Random Agent
# Here, an agent performs actions by taking steps based on random samples of the action-space. We record the means of the rewards and steps across multiple trials. Note that given the current reward configuration, this is somewhat redundant.

# %%
class Agent:
    def __init__(self, Env, policy):
        self.Env = Env
        self.policy = policy

    def run_episode(self):
        self.Env.reset()
        total_reward = 0
        total_steps = 0
        while True:
            action = self.policy()
            obs,reward,done,trunc,_ = self.Env.step(action)
            total_reward += reward
            total_steps += 1
            if done:
                break
        return total_steps, total_reward
    

def collect_episodes(agent, num_episodes, verbose = False):
    e_steps = []
    e_rewards = []
    for i in range(num_episodes):
        s,r = agent.run_episode()
        e_steps.append(s)
        e_rewards.append(r)
    if verbose:
        print(f"{num_episodes} Episode Sampling:\n  Avg. Steps: {sum(e_steps)/len(e_steps)}\n  Avg. Reward: {sum(e_rewards)/len(e_rewards)}")
    return e_steps, e_rewards

rand_agent = Agent(Env, Env.action_space.sample)
e_steps, e_rewards = collect_episodes(rand_agent, 500, True)
# Out:
# 500 Episode Sampling:
#   Avg. Steps: 22.742
#   Avg. Reward: 22.742

# %% [markdown]
# ### Environment Wrappers
#
# Gym's `Environment` class is responsible for the 3 communication channels between the agent and the environment. The `action_space`, `observation_space` and `reward`.
#
# We can alter the default Environment class using `Wrapper`, which inherits from `Environment`.
#
# Additionally, we can specifically alter the behaviour of any of these 3 communication channels using the `ActionWrapper`, `ObservationWrapper`, and `RewardWrapper` classes specifically, to only expose the exact methods we want to override. Namely, the `action(action)`, `reward(reward)` and `observe(obs)` methods, respectively.
#
# An example `ActionWrapper` is implemented below to introduce a probability of random-choice override of the action that was originally sent to the environment by the agent.

# %%
import random
import numpy as np

# Implement an Epsilon % chance that a random action is taken
# instead of the one sent to the environment by the .step()
# method
class RandActionWrapper(gym.ActionWrapper):
    def __init__(self, env: Env, epsilon = 0.1):
        super().__init__(env)
        self.epsilon = epsilon

    def action(self, action):
        if random.random() < self.epsilon:
            # print("Random Action Taken!")
            return self.env.action_space.sample()
        return action

def left_policy():
    return 0

best_avg_reward = 0
best_epsilon = 9999
epsilon = 0
while epsilon <= 1:
    Env = RandActionWrapper(gym.make("CartPole-v1"), epsilon)
    left_agent = Agent(Env, left_policy)
    _,episode_rewards = collect_episodes(left_agent,500,False)
    avg_reward = np.mean(episode_rewards)
    if avg_reward > best_avg_reward:
        best_avg_reward = avg_reward
        best_epsilon = epsilon
    epsilon += 0.1
print(f"Highest Avg. Reward Achieved at Epsilon = {best_epsilon}")
print(f"Avg. Reward Achieved: {best_avg_reward}")
# Out:
# Highest Avg. Reward Achieved at Epsilon = 0.9999999999999999
# Avg. Reward Achieved: 22.078

# %% [markdown]
# Notice that our left_only agent performs best when it's partically replaced by the random agent by setting the random-action probability for the left-agent very close to 100%

# %%
ACTION = 0
def left_right_policy():
    global ACTION 
    action = 0 if ACTION % 4 > 1 else 1
    ACTION += 1
    return action

Env = gym.make('CartPole-v1', render_mode="human")
LR_agent = Agent(Env,left_right_policy)
_,_ = collect_episodes(LR_agent, 10,True)
Env.close()
# Out:
# 10 Episode Sampling:
#   Avg. Steps: 38.0
#   Avg. Reward: 38.0

# %% [markdown]
# ### A Deep RL Cart World
# This diverges from the ordering of content in the Maxim Lapan book, as he chooses to step back from the CartPole environment for a stretch of time.
#
# For the sake of completeness, we use some very high level libraries from pytorch to implement a deep RL agent that learns how to balance the pole very well.
#
# Credit to [PyTorch.org](https://pytorch.org/tutorials/intermediate/reinforcement_q_learning.html) for the following code sections

# %% [markdown]
# ##### Imports and Setup

# %%
import gym
import math
import random
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple, deque
from itertools import count

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

env = gym.make("CartPole-v1")

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ##### Replay Memory
# Two data structures:
# 1. `Transition` pairs a (state, action) with a (next_state,reward) into a single Tuple. Represents a single transition in the MDP that comprises our environment.
# 2. `ReplayMemory` is a bounded size buffer that holds recent transitions and provides a way to sample them.

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):

    def __init__(self, capacity):
        self.memory = deque([], maxlen=capacity)

    def push(self, *args):
        """Save a transition"""
        self.memory.append(Transition(*args))

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# ##### DQN Algorithm Overview:
# This environment is deterministic, which is simpler than most RL environments. Standard RL literature will utilize expectations over stochastic transitions.
#
# The goal of our policy is to maximize the discounted cumulative reward $R_{t0} = \sum^{\infty}_{t=t_0}\gamma^{t-t_0}r_t$, where $R_{t0}$ is also known as <i>return.</i> The discount, $\gamma$, is a constant, $\gamma \in[0,1]$. This ensures that the sum will converge as time, or $t$, progresses. Intuitively, this means that the far-future is less important to our agent, which is preferable in many cases. It does also encourage the agent to strongly prefer to choose near-term rewards over long term ones, however.
#
# The notion of Q learning is that we attempt to emulate a perfect function that maps a $State \times Action$ pair to a perfectly-known return, $R$. If we had this function, called $Q^*$, then an optimal decision policy $\pi^*(s)$ would be simple: $$\pi^*(s) = argmax_{a}(Q^*(s,a))$$
#
# Unfortunately, we aren't God, and do not have access to $Q^*$ for even  relatively simple scenarios. Thankfully, <i>neural networks</i>  allow us to play God somewhat, by serving as a very reliable and very flexible <i>function approximation tool</i> that can produce results similar to $Q^*$.

# %% [markdown]
# There is a useful fact which I won't relate the details of at this time that will be useful for defining a training-update rule. That is that every $Q$ function for some policy obeys the bellman equation: $$Q^\pi (s,a) = r+ \gamma Q^\pi(s', \pi(s'))$$
#
# The difference between the two sides of the equality above are what defines the temporal difference error, often referred to as $\delta$:
#
# $$\delta = Q(s,a) - (r+\gamma \max_{a}^{'}Q(s',a))$$
#
# PyTorch suggests using Huber Loss. It's better at not over-reacting to outliers than MSE, since it doesn't square the error if it's too large. However, in practice we've determined that MSE works quite well with our chosen hyperparameters, and avoids the need for a conditional. This loss is calculated over a batch of transitions, $B$, from the replay memory.
#
# $$\mathit{L} = \frac{1}{|B|}\sum_{(s,a,s',r)\in B} \mathit{L}(\delta)$$
#
# $$where \quad \mathit{L}(\delta)=
# \begin{cases}
# \frac{1}{2}\delta^2 & \text{for } |\delta| \leq 1\\
# |\delta|-\frac{1}{2} & \text{otherwise.}
# \end{cases}$$

# %% [markdown]
# <h5 style="margin-bottom:8px; font-weight:bold; font-style: italic">The Q-Network:</h5>
# A Feed Forward neural network that takes in the difference between the current and previous states as input in the form of a 4Tuple (s,a,r,s')
#
# It has two outputs, representing $Q(s,left)$ and $Q(s,right)$. In effect, the network is trying to predict the expected return of taking each action given the current input.
#
# After allowing the network to estimate the quality of our possible actions, the agent moves, collects information about the state change, and stores it in the replay memory.
#
# **Note:** After some extensive trial and error, we went with a slightly different setup for the DQN than the one perscribed by the PyTorch docs. The baseline work for this model can be credited to [Andrew Gordienko](https://andrew-gordienko.medium.com/reinforcement-learning-dqn-w-pytorch-7c6faad3d1e), who's model I only slightly tuned/adjusted to achieve an infallible agent.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import math
import gym
import random
import numpy as np
import matplotlib.pyplot as plt

env = gym.make('CartPole-v1', render_mode="human")
env.reset()
observation_space = env.observation_space.shape[0]
action_space = env.action_space.n

EPISODES = 400
LEARNING_RATE = 0.0001
MEM_SIZE = 500000
BATCH_SIZE = 128
GAMMA = 0.999
EXPLORATION_MAX = 1.0
EXPLORATION_DECAY = 0.9995
EXPLORATION_MIN = 0

FC1_DIMS = 512
FC2_DIMS = 1024
DEVICE = torch.device("cuda")

best_reward = 0
average_reward = 0
episode_number = []
average_reward_number = []

class Network(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.input_shape = env.observation_space.shape
        self.action_space = action_space

        self.fc1 = nn.Linear(*self.input_shape, FC1_DIMS)
        self.fc2 = nn.Linear(FC1_DIMS, FC2_DIMS)
        self.fc3 = nn.Linear(FC2_DIMS, 512)
        self.fc4 = nn.Linear(512, self.action_space)

        self.optimizer = optim.Adam(self.parameters(), lr=LEARNING_RATE)
        self.loss = nn.MSELoss()
        self.to(DEVICE)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)

        return x

class ReplayBuffer:
    def __init__(self):
        self.mem_count = 0
        
        self.states = np.zeros((MEM_SIZE, *env.observation_space.shape),dtype=np.float32)
        self.actions = np.zeros(MEM_SIZE, dtype=np.int64)
        self.rewards = np.zeros(MEM_SIZE, dtype=np.float32)
        self.states_ = np.zeros((MEM_SIZE, *env.observation_space.shape),dtype=np.float32)
        self.dones = np.zeros(MEM_SIZE, dtype=np.bool)
    
    def add(self, state, action, reward, state_, done):
        mem_index = self.mem_count % MEM_SIZE
        
        self.states[mem_index]  = state
        self.actions[mem_index] = action
        self.rewards[mem_index] = reward
        self.states_[mem_index] = state_
        self.dones[mem_index] =  1 - done

        self.mem_count += 1
    
    def sample(self):
        MEM_MAX = min(self.mem_count, MEM_SIZE)
        batch_indices = np.random.choice(MEM_MAX, BATCH_SIZE, replace=True)
        
        states  = self.states[batch_indices]
        actions = self.actions[batch_indices]
        rewards = self.rewards[batch_indices]
        states_ = self.states_[batch_indices]
        dones   = self.dones[batch_indices]

        return states, actions, rewards, states_, dones

class DQN_Solver:
    def __init__(self, network = Network(), exploration_rate = EXPLORATION_MAX):
        self.memory = ReplayBuffer()
        self.exploration_rate = exploration_rate
        self.network = network

    def choose_action(self, observation):
        if random.random() < self.exploration_rate:
            return env.action_space.sample()
        
        state = torch.tensor(observation).float().detach()
        state = state.to(DEVICE)
        state = state.unsqueeze(0)
        q_values = self.network(state)
        return torch.argmax(q_values).item()
    
    def learn(self):
        if self.memory.mem_count < BATCH_SIZE:
            return
        
        states, actions, rewards, states_, dones = self.memory.sample()
        states = torch.tensor(states , dtype=torch.float32).to(DEVICE)
        actions = torch.tensor(actions, dtype=torch.long).to(DEVICE)
        rewards = torch.tensor(rewards, dtype=torch.float32).to(DEVICE)
        states_ = torch.tensor(states_, dtype=torch.float32).to(DEVICE)
        dones = torch.tensor(dones, dtype=torch.bool).to(DEVICE)
        batch_indices = np.arange(BATCH_SIZE, dtype=np.int64)

        q_values = self.network(states)
        next_q_values = self.network(states_)
        
        predicted_value_of_now = q_values[batch_indices, actions]
        predicted_value_of_future = torch.max(next_q_values, dim=1)[0]
        
        q_target = rewards + GAMMA * predicted_value_of_future * dones

        loss = self.network.loss(q_target, predicted_value_of_now)
        self.network.optimizer.zero_grad()
        loss.backward()
        self.network.optimizer.step()

        self.exploration_rate *= EXPLORATION_DECAY
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)

    def returning_epsilon(self):
        return self.exploration_rate

agent = DQN_Solver()

if NEW_TRAINING:
    for i in range(1, EPISODES):
        state = env.reset()[0]
        state = np.reshape(state, [1, observation_space])
        score = 0
        
        while True:
            
            env.render()
            action = agent.choose_action(state)
            state_, reward, done, trunc, info = env.step(action)
            state_ = np.reshape(state_, [1, observation_space])
            agent.memory.add(state, action, reward, state_, done)
            agent.learn()
            state = state_
            score += reward

            if done or score > 10000:
                if score > best_reward:
                    best_reward = score
                average_reward += score 
                print("Episode {} Average Reward {} Best Reward {} Last Reward {} Epsilon {}".format(i, average_reward/i, best_reward, score, agent.returning_epsilon()))
                break
        
            episode_number.append(i)
            average_reward_number.append(average_reward/i)
            
            if average_reward/i > 500:
                break

    plt.plot(episode_number, average_reward_number)
    plt.show()
# Out:
# C:\Users\jfrie\AppData\Local\Temp\ipykernel_26564\435640068.py:65: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.dones = np.zeros(MEM_SIZE, dtype=np.bool)
# Episode 1 Average Reward 13.0 Best Reward 13.0 Last Reward 13.0 Epsilon 1.0
# Episode 2 Average Reward 12.0 Best Reward 13.0 Last Reward 11.0 Epsilon 1.0
# Episode 3 Average Reward 18.666666666666668 Best Reward 32.0 Last Reward 32.0 Epsilon 1.0
# Episode 4 Average Reward 18.0 Best Reward 32.0 Last Reward 16.0 Epsilon 1.0
# Episode 5 Average Reward 23.4 Best Reward 45.0 Last Reward 45.0 Epsilon 1.0
# Episode 6 Average Reward 22.5 Best Reward 45.0 Last Reward 18.0 Epsilon 0.9960069930043736
# Episode 7 Average Reward 21.571428571428573 Best Reward 45.0 Last Reward 16.0 Epsilon 0.9880687476628001
# Episode 8 Average Reward 22.75 Best Reward 45.0 Last Reward 31.0 Epsilon 0.9728679918326804
# Episode 9 Average Reward 23.22222222222222 Best Reward 45.0 Last Reward 27.0 Epsilon 0.9598192884690291
# Episode 10 Average Reward 22.3 Best Reward 45.0 Last Reward 14.0 Epsilon 0.9531223457267703
# Episode 11 Average Reward 24.454545454545453 Best Reward 46.0 Last Reward 46.0 Epsilon 0.9314453533126285
# Episode 12 Average Reward 23.583333333333332 Best Reward 46.0 Last Reward 14.0 Epsilon 0.9249463838986807
# Episode 13 Average Reward 25.46153846153846 Best Reward 48.0 Last Reward 48.0 Epsilon 0.9030065170304803
# Episode 14 Average Reward 24.285714285714285 Best Reward 48.0 Last Reward 9.0 Epsilon 0.8989511052880362
# Episode 15 Average Reward 24.133333333333333 Best Reward 48.0 Last Reward 22.0 Epsilon 0.889114384918362
# Episode 16 Average Reward 25.0 Best Reward 48.0 Last Reward 38.0 Epsilon 0.8723765399749112
# Episode 17 Average Reward 24.823529411764707 Best Reward 48.0 Last Reward 22.0 Epsilon 0.8628306102460106
# Episode 18 Average Reward 24.77777777777778 Best Reward 48.0 Last Reward 24.0 Epsilon 0.8525359605109053
# Episode 19 Average Reward 24.94736842105263 Best Reward 48.0 Last Reward 28.0 Epsilon 0.8406806736869129
# Episode 20 Average Reward 24.85 Best Reward 48.0 Last Reward 23.0 Epsilon 0.8310658333508228
# Episode 21 Average Reward 24.095238095238095 Best Reward 48.0 Last Reward 9.0 Epsilon 0.827333507973595
# Episode 22 Average Reward 24.09090909090909 Best Reward 48.0 Last Reward 24.0 Epsilon 0.8174623831229412
# Episode 23 Average Reward 23.652173913043477 Best Reward 48.0 Last Reward 14.0 Epsilon 0.8117587065668503
# Episode 24 Average Reward 23.208333333333332 Best Reward 48.0 Last Reward 13.0 Epsilon 0.8064980752848135
# Episode 25 Average Reward 23.76 Best Reward 48.0 Last Reward 37.0 Epsilon 0.7917113628284419
# Episode 26 Average Reward 23.615384615384617 Best Reward 48.0 Last Reward 20.0 Epsilon 0.7838317429103805
# Episode 27 Average Reward 23.444444444444443 Best Reward 48.0 Last Reward 19.0 Epsilon 0.776418755407721
# Episode 28 Average Reward 23.214285714285715 Best Reward 48.0 Last Reward 17.0 Epsilon 0.7698455283441881
# Episode 29 Average Reward 22.96551724137931 Best Reward 48.0 Last Reward 16.0 Epsilon 0.7637098056815635
# Episode 30 Average Reward 22.8 Best Reward 48.0 Last Reward 18.0 Epsilon 0.7568655515779528
# Episode 31 Average Reward 22.903225806451612 Best Reward 48.0 Last Reward 26.0 Epsilon 0.747087549457845
# Episode 32 Average Reward 22.8125 Best Reward 48.0 Last Reward 20.0 Epsilon 0.7396520543877567
# Episode 33 Average Reward 22.666666666666668 Best Reward 48.0 Last Reward 18.0 Epsilon 0.7330234022860987
# Episode 34 Average Reward 22.5 Best Reward 48.0 Last Reward 17.0 Epsilon 0.7268175639642518
# Episode 35 Average Reward 22.142857142857142 Best Reward 48.0 Last Reward 10.0 Epsilon 0.7231916419492961
# Episode 36 Average Reward 22.583333333333332 Best Reward 48.0 Last Reward 38.0 Epsilon 0.7095773424028339
# Episode 37 Average Reward 22.2972972972973 Best Reward 48.0 Last Reward 12.0 Epsilon 0.705331566883125
# Episode 38 Average Reward 22.026315789473685 Best Reward 48.0 Last Reward 12.0 Epsilon 0.7011111960778661
# Episode 39 Average Reward 22.564102564102566 Best Reward 48.0 Last Reward 43.0 Epsilon 0.6861945050497837
# Episode 40 Average Reward 22.3 Best Reward 48.0 Last Reward 12.0 Epsilon 0.6820886413796821
# Episode 41 Average Reward 22.70731707317073 Best Reward 48.0 Last Reward 39.0 Epsilon 0.6689134940867506
# Episode 42 Average Reward 22.928571428571427 Best Reward 48.0 Last Reward 32.0 Epsilon 0.658293410227447
# Episode 43 Average Reward 22.790697674418606 Best Reward 48.0 Last Reward 17.0 Epsilon 0.6527202423593162
# Episode 44 Average Reward 22.522727272727273 Best Reward 48.0 Last Reward 11.0 Epsilon 0.6491392424807709
# Episode 45 Average Reward 24.0 Best Reward 89.0 Last Reward 89.0 Epsilon 0.6208789368762069
# Episode 46 Average Reward 24.369565217391305 Best Reward 89.0 Last Reward 41.0 Epsilon 0.6082773754464013
# Episode 47 Average Reward 24.425531914893618 Best Reward 89.0 Last Reward 27.0 Epsilon 0.6001187854818283
# Episode 48 Average Reward 25.104166666666668 Best Reward 89.0 Last Reward 57.0 Epsilon 0.5832526672941704
# Episode 49 Average Reward 24.897959183673468 Best Reward 89.0 Last Reward 15.0 Epsilon 0.5788935495491895
# Episode 50 Average Reward 24.76 Best Reward 89.0 Last Reward 18.0 Epsilon 0.5737055913449342
# Episode 51 Average Reward 26.666666666666668 Best Reward 122.0 Last Reward 122.0 Epsilon 0.5397473191725894
# Episode 52 Average Reward 27.115384615384617 Best Reward 122.0 Last Reward 50.0 Epsilon 0.5264176191622251
# Episode 53 Average Reward 26.9811320754717 Best Reward 122.0 Last Reward 20.0 Epsilon 0.521178372952154
# Episode 54 Average Reward 28.85185185185185 Best Reward 128.0 Last Reward 128.0 Epsilon 0.4888600950440462
# Episode 55 Average Reward 29.327272727272728 Best Reward 128.0 Last Reward 55.0 Epsilon 0.47559633895263465
# Episode 56 Average Reward 30.714285714285715 Best Reward 128.0 Last Reward 107.0 Epsilon 0.4508145635170906
# Episode 57 Average Reward 30.789473684210527 Best Reward 128.0 Last Reward 35.0 Epsilon 0.4429919999699293
# Episode 58 Average Reward 31.362068965517242 Best Reward 128.0 Last Reward 64.0 Epsilon 0.42903723432316415
# Episode 59 Average Reward 31.677966101694917 Best Reward 128.0 Last Reward 50.0 Epsilon 0.4184416511240273
# Episode 60 Average Reward 31.8 Best Reward 128.0 Last Reward 39.0 Epsilon 0.4103590793692694
# Episode 61 Average Reward 31.934426229508198 Best Reward 128.0 Last Reward 40.0 Epsilon 0.4022314133444051
# Episode 62 Average Reward 32.016129032258064 Best Reward 128.0 Last Reward 37.0 Epsilon 0.3948567147154674
# Episode 63 Average Reward 33.492063492063494 Best Reward 128.0 Last Reward 125.0 Epsilon 0.37092775801915756
# Episode 64 Average Reward 35.3125 Best Reward 150.0 Last Reward 150.0 Epsilon 0.34411935695070367
# Episode 65 Average Reward 35.49230769230769 Best Reward 150.0 Last Reward 47.0 Epsilon 0.33612485665139746
# Episode 66 Average Reward 36.46969696969697 Best Reward 150.0 Last Reward 100.0 Epsilon 0.31972785599700076
# Episode 67 Average Reward 38.940298507462686 Best Reward 202.0 Last Reward 202.0 Epsilon 0.2890052706608178
# Episode 68 Average Reward 40.411764705882355 Best Reward 202.0 Last Reward 139.0 Epsilon 0.269596809490205
# Episode 69 Average Reward 41.95652173913044 Best Reward 202.0 Last Reward 147.0 Epsilon 0.250487536201816
# Episode 70 Average Reward 42.34285714285714 Best Reward 202.0 Last Reward 69.0 Epsilon 0.24199100008400556
# Episode 71 Average Reward 44.25352112676056 Best Reward 202.0 Last Reward 178.0 Epsilon 0.22137946788119997
# Episode 72 Average Reward 44.291666666666664 Best Reward 202.0 Last Reward 47.0 Epsilon 0.21623643193600012
# Episode 73 Average Reward 45.26027397260274 Best Reward 202.0 Last Reward 115.0 Epsilon 0.20415061322507186
# Episode 74 Average Reward 48.83783783783784 Best Reward 310.0 Last Reward 310.0 Epsilon 0.17483090657048322
# Episode 75 Average Reward 51.093333333333334 Best Reward 310.0 Last Reward 218.0 Epsilon 0.15677191832298015
# Episode 76 Average Reward 54.671052631578945 Best Reward 323.0 Last Reward 323.0 Epsilon 0.1333865909864099
# Episode 77 Average Reward 55.5974025974026 Best Reward 323.0 Last Reward 126.0 Epsilon 0.12524049587321898
# Episode 78 Average Reward 58.166666666666664 Best Reward 323.0 Last Reward 256.0 Epsilon 0.11018974619567216
# Episode 79 Average Reward 58.265822784810126 Best Reward 323.0 Last Reward 66.0 Epsilon 0.10661194847014373
# Episode 80 Average Reward 58.4 Best Reward 323.0 Last Reward 69.0 Epsilon 0.10299567165053818
# Episode 81 Average Reward 59.592592592592595 Best Reward 323.0 Last Reward 155.0 Epsilon 0.09531313061568897
# Episode 82 Average Reward 60.28048780487805 Best Reward 323.0 Last Reward 116.0 Epsilon 0.0899409261077647
# Episode 83 Average Reward 60.602409638554214 Best Reward 323.0 Last Reward 87.0 Epsilon 0.08611143382145525
# Episode 84 Average Reward 61.54761904761905 Best Reward 323.0 Last Reward 140.0 Epsilon 0.08028836319118277
# Episode 85 Average Reward 62.45882352941177 Best Reward 323.0 Last Reward 139.0 Epsilon 0.07489651142361771
# Episode 86 Average Reward 62.94186046511628 Best Reward 323.0 Last Reward 104.0 Epsilon 0.0711004956995951
# Episode 87 Average Reward 64.93103448275862 Best Reward 323.0 Last Reward 236.0 Epsilon 0.06318486526458533
# Episode 88 Average Reward 68.7840909090909 Best Reward 404.0 Last Reward 404.0 Epsilon 0.051625424911221574
# Episode 89 Average Reward 72.3932584269663 Best Reward 404.0 Last Reward 390.0 Epsilon 0.04247711735333018
# Episode 90 Average Reward 77.32222222222222 Best Reward 516.0 Last Reward 516.0 Epsilon 0.03281550096691258
# Episode 91 Average Reward 78.23076923076923 Best Reward 516.0 Last Reward 160.0 Epsilon 0.030291919310953156
# Episode 92 Average Reward 77.93478260869566 Best Reward 516.0 Last Reward 51.0 Epsilon 0.02952905253505858
# Episode 93 Average Reward 83.11827956989248 Best Reward 560.0 Last Reward 560.0 Epsilon 0.02231601510991787
# Episode 94 Average Reward 89.14893617021276 Best Reward 650.0 Last Reward 650.0 Epsilon 0.01612262088818654
# Episode 95 Average Reward 92.8 Best Reward 650.0 Last Reward 436.0 Epsilon 0.012963902854964739
# Episode 96 Average Reward 96.34375 Best Reward 650.0 Last Reward 433.0 Epsilon 0.010439687496872373
# Episode 97 Average Reward 100.43298969072166 Best Reward 650.0 Last Reward 493.0 Epsilon 0.008158440236419272
# Episode 98 Average Reward 100.79591836734694 Best Reward 650.0 Last Reward 136.0 Epsilon 0.007621978620982431
# Episode 99 Average Reward 101.25252525252525 Best Reward 650.0 Last Reward 146.0 Epsilon 0.007085268302058724
# Episode 100 Average Reward 105.34 Best Reward 650.0 Last Reward 510.0 Epsilon 0.0054901411753731375
# Episode 101 Average Reward 106.67326732673267 Best Reward 650.0 Last Reward 240.0 Epsilon 0.004869172282829768
# Episode 102 Average Reward 106.73529411764706 Best Reward 650.0 Last Reward 113.0 Epsilon 0.004601626511627212
# Episode 103 Average Reward 107.0 Best Reward 650.0 Last Reward 134.0 Epsilon 0.004303346926316761
# Episode 104 Average Reward 109.6923076923077 Best Reward 650.0 Last Reward 387.0 Epsilon 0.0035460867933579253
# Episode 105 Average Reward 114.76190476190476 Best Reward 650.0 Last Reward 642.0 Epsilon 0.0025722073131734273
# Episode 106 Average Reward 116.64150943396227 Best Reward 650.0 Last Reward 314.0 Epsilon 0.0021983897134260624
# Episode 107 Average Reward 116.37383177570094 Best Reward 650.0 Last Reward 88.0 Epsilon 0.002103734587406708
# Episode 108 Average Reward 117.08333333333333 Best Reward 650.0 Last Reward 193.0 Epsilon 0.0019101657286171075
# Episode 109 Average Reward 120.88073394495413 Best Reward 650.0 Last Reward 531.0 Epsilon 0.001464660697834423
# Episode 110 Average Reward 125.2090909090909 Best Reward 650.0 Last Reward 597.0 Epsilon 0.001086595007139845
# Episode 111 Average Reward 127.57657657657657 Best Reward 650.0 Last Reward 388.0 Epsilon 0.0008949391462940356
# Episode 112 Average Reward 130.70535714285714 Best Reward 650.0 Last Reward 478.0 Epsilon 0.0007046462846961899
# Episode 113 Average Reward 131.71681415929203 Best Reward 650.0 Last Reward 245.0 Epsilon 0.000623385631123614
# Episode 114 Average Reward 134.42105263157896 Best Reward 650.0 Last Reward 440.0 Epsilon 0.0005002511636105563
# Episode 115 Average Reward 134.80869565217392 Best Reward 650.0 Last Reward 179.0 Epsilon 0.00045741355546457255
# Episode 116 Average Reward 135.0 Best Reward 650.0 Last Reward 157.0 Epsilon 0.0004228714725661581
# Episode 117 Average Reward 136.8803418803419 Best Reward 650.0 Last Reward 355.0 Epsilon 0.0003540803609543113
# Episode 118 Average Reward 137.3728813559322 Best Reward 650.0 Last Reward 195.0 Epsilon 0.00032117929306927636
# Episode 119 Average Reward 141.41176470588235 Best Reward 650.0 Last Reward 618.0 Epsilon 0.00023578543949912684
# Episode 120 Average Reward 146.18333333333334 Best Reward 714.0 Last Reward 714.0 Epsilon 0.00016498143576703953
# Episode 121 Average Reward 149.82644628099175 Best Reward 714.0 Last Reward 587.0 Epsilon 0.00012300925022187218
# Episode 122 Average Reward 153.37704918032787 Best Reward 714.0 Last Reward 583.0 Epsilon 9.189867930890509e-05
# Episode 123 Average Reward 156.17073170731706 Best Reward 714.0 Last Reward 497.0 Epsilon 7.167374575683719e-05
# Episode 124 Average Reward 160.41129032258064 Best Reward 714.0 Last Reward 682.0 Epsilon 5.095990943868284e-05
# Episode 125 Average Reward 162.688 Best Reward 714.0 Last Reward 445.0 Epsilon 4.0791902378944635e-05
# Episode 126 Average Reward 162.484126984127 Best Reward 714.0 Last Reward 137.0 Epsilon 3.8090559142710556e-05
# Episode 127 Average Reward 165.88976377952756 Best Reward 714.0 Last Reward 595.0 Epsilon 2.828670935100594e-05
# Episode 128 Average Reward 167.2890625 Best Reward 714.0 Last Reward 345.0 Epsilon 2.380388781042801e-05
# Episode 129 Average Reward 171.35658914728683 Best Reward 714.0 Last Reward 692.0 Epsilon 1.6840090650936564e-05
# Episode 130 Average Reward 173.3230769230769 Best Reward 714.0 Last Reward 427.0 Epsilon 1.3601893337889156e-05
# Episode 131 Average Reward 176.68702290076337 Best Reward 714.0 Last Reward 614.0 Epsilon 1.000547280189859e-05
# Episode 132 Average Reward 179.07575757575756 Best Reward 714.0 Last Reward 492.0 Epsilon 7.823020263709338e-06
# Episode 133 Average Reward 180.75187969924812 Best Reward 714.0 Last Reward 402.0 Epsilon 6.398223899940859e-06
# Episode 134 Average Reward 185.2910447761194 Best Reward 789.0 Last Reward 789.0 Epsilon 4.312086002502403e-06
# Episode 135 Average Reward 187.37037037037038 Best Reward 789.0 Last Reward 466.0 Epsilon 3.4156353033262794e-06
# Episode 136 Average Reward 188.18382352941177 Best Reward 789.0 Last Reward 298.0 Epsilon 2.9426962310747403e-06
# Episode 137 Average Reward 189.05839416058393 Best Reward 789.0 Last Reward 308.0 Epsilon 2.5225939911113625e-06
# Episode 138 Average Reward 190.70289855072463 Best Reward 789.0 Last Reward 416.0 Epsilon 2.0487620164260775e-06
# Episode 139 Average Reward 192.53237410071944 Best Reward 789.0 Last Reward 445.0 Epsilon 1.6399734829258425e-06
# Episode 140 Average Reward 192.2642857142857 Best Reward 789.0 Last Reward 155.0 Epsilon 1.5176463659049357e-06
# Episode 141 Average Reward 194.56028368794327 Best Reward 789.0 Last Reward 516.0 Epsilon 1.1724506955950567e-06
# Episode 142 Average Reward 198.21830985915494 Best Reward 789.0 Last Reward 714.0 Epsilon 8.203755055284187e-07
# Episode 143 Average Reward 199.12587412587413 Best Reward 789.0 Last Reward 328.0 Epsilon 6.962586085555411e-07
# Episode 144 Average Reward 199.59027777777777 Best Reward 789.0 Last Reward 266.0 Epsilon 6.095298329083439e-07
# Episode 145 Average Reward 201.4551724137931 Best Reward 789.0 Last Reward 470.0 Epsilon 4.818481990228619e-07
# Episode 146 Average Reward 204.76712328767124 Best Reward 789.0 Last Reward 685.0 Epsilon 3.420796043063862e-07
# Episode 147 Average Reward 205.72108843537416 Best Reward 789.0 Last Reward 345.0 Epsilon 2.8786750774371124e-07
# Episode 148 Average Reward 208.80405405405406 Best Reward 789.0 Last Reward 662.0 Epsilon 2.0673081867236533e-07
# Episode 149 Average Reward 210.40268456375838 Best Reward 789.0 Last Reward 447.0 Epsilon 1.653164739038831e-07
# Episode 150 Average Reward 211.89333333333335 Best Reward 789.0 Last Reward 434.0 Epsilon 1.330609631047925e-07
# Episode 151 Average Reward 215.20529801324503 Best Reward 789.0 Last Reward 712.0 Epsilon 9.319726378531267e-08
# Episode 152 Average Reward 217.51315789473685 Best Reward 789.0 Last Reward 566.0 Epsilon 7.022101246744914e-08
# Episode 153 Average Reward 223.281045751634 Best Reward 1100.0 Last Reward 1100.0 Epsilon 4.050842767848024e-08
# Episode 154 Average Reward 224.9805194805195 Best Reward 1100.0 Last Reward 485.0 Epsilon 3.178356709098138e-08
# Episode 155 Average Reward 229.3483870967742 Best Reward 1100.0 Last Reward 902.0 Epsilon 2.0243557817691445e-08
# Episode 156 Average Reward 233.19871794871796 Best Reward 1100.0 Last Reward 830.0 Epsilon 1.3366249369019574e-08
# Episode 157 Average Reward 235.38216560509554 Best Reward 1100.0 Last Reward 576.0 Epsilon 1.0020778646537246e-08
# Episode 158 Average Reward 238.22151898734177 Best Reward 1100.0 Last Reward 684.0 Epsilon 7.117633334743344e-09
# Episode 159 Average Reward 240.22012578616352 Best Reward 1100.0 Last Reward 556.0 Epsilon 5.389786373016639e-09
# Episode 160 Average Reward 241.18125 Best Reward 1100.0 Last Reward 394.0 Epsilon 4.425824035188079e-09
# Episode 161 Average Reward 242.27950310559007 Best Reward 1100.0 Last Reward 418.0 Epsilon 3.590904843699596e-09
# Episode 162 Average Reward 244.89506172839506 Best Reward 1100.0 Last Reward 666.0 Epsilon 2.573639226177853e-09
# Episode 163 Average Reward 247.64417177914112 Best Reward 1100.0 Last Reward 693.0 Epsilon 1.8198139756703258e-09
# Episode 164 Average Reward 250.1951219512195 Best Reward 1100.0 Last Reward 666.0 Epsilon 1.3042797946454394e-09
# Episode 165 Average Reward 254.01818181818183 Best Reward 1100.0 Last Reward 881.0 Epsilon 8.394913092696133e-10
# Episode 166 Average Reward 254.53614457831324 Best Reward 1100.0 Last Reward 340.0 Epsilon 7.082191714775172e-10
# Episode 167 Average Reward 256.6646706586826 Best Reward 1100.0 Last Reward 610.0 Epsilon 5.220050878092803e-10
# Episode 168 Average Reward 264.5892857142857 Best Reward 1588.0 Last Reward 1588.0 Epsilon 2.359166980626742e-10
# Episode 169 Average Reward 269.32544378698225 Best Reward 1588.0 Last Reward 1065.0 Epsilon 1.3849657540627713e-10
# Episode 170 Average Reward 273.08235294117645 Best Reward 1588.0 Last Reward 908.0 Epsilon 8.794679779722928e-11
# Episode 171 Average Reward 276.1169590643275 Best Reward 1588.0 Last Reward 792.0 Epsilon 5.918292245046858e-11
# Episode 172 Average Reward 277.97093023255815 Best Reward 1588.0 Last Reward 595.0 Epsilon 4.395026388631801e-11
# Episode 173 Average Reward 280.9942196531792 Best Reward 1588.0 Last Reward 801.0 Epsilon 2.944306710426808e-11
# Episode 174 Average Reward 283.4425287356322 Best Reward 1588.0 Last Reward 707.0 Epsilon 2.0673859279783654e-11
# Episode 175 Average Reward 286.6857142857143 Best Reward 1588.0 Last Reward 851.0 Epsilon 1.3507750813478523e-11
# Episode 176 Average Reward 289.5511363636364 Best Reward 1588.0 Last Reward 791.0 Epsilon 9.094453725988976e-12
# Episode 177 Average Reward 291.361581920904 Best Reward 1588.0 Last Reward 610.0 Epsilon 6.703223108050259e-12
# Episode 178 Average Reward 293.6292134831461 Best Reward 1588.0 Last Reward 695.0 Epsilon 4.735093948161907e-12
# Episode 179 Average Reward 295.3296089385475 Best Reward 1588.0 Last Reward 598.0 Epsilon 3.5110909204385273e-12
# Episode 180 Average Reward 298.3666666666667 Best Reward 1588.0 Last Reward 842.0 Epsilon 2.3044026932911013e-12
# Episode 181 Average Reward 300.74585635359114 Best Reward 1588.0 Last Reward 729.0 Epsilon 1.6003627979314596e-12
# Episode 182 Average Reward 302.7857142857143 Best Reward 1588.0 Last Reward 672.0 Epsilon 1.1435601379697294e-12
# Episode 183 Average Reward 305.26229508196724 Best Reward 1588.0 Last Reward 756.0 Epsilon 7.835282142749199e-13
# Episode 184 Average Reward 306.7228260869565 Best Reward 1588.0 Last Reward 574.0 Epsilon 5.880049097528532e-13
# Episode 185 Average Reward 312.28648648648647 Best Reward 1588.0 Last Reward 1336.0 Epsilon 3.014391712545928e-13
# Episode 186 Average Reward 314.247311827957 Best Reward 1588.0 Last Reward 677.0 Epsilon 2.1485934159236885e-13
# Episode 187 Average Reward 317.09090909090907 Best Reward 1588.0 Last Reward 846.0 Epsilon 1.407348753383297e-13
# Episode 188 Average Reward 322.00531914893617 Best Reward 1588.0 Last Reward 1241.0 Epsilon 7.565795778874485e-14
# Episode 189 Average Reward 326.35449735449737 Best Reward 1588.0 Last Reward 1144.0 Epsilon 4.2694904441965443e-14
# Episode 190 Average Reward 328.4526315789474 Best Reward 1588.0 Last Reward 725.0 Epsilon 2.9710155517632626e-14
# Episode 191 Average Reward 329.9947643979058 Best Reward 1588.0 Last Reward 623.0 Epsilon 2.1756466485263932e-14
# Episode 192 Average Reward 331.5260416666667 Best Reward 1588.0 Last Reward 624.0 Epsilon 1.59240890451303e-14
# Episode 193 Average Reward 332.81865284974094 Best Reward 1588.0 Last Reward 581.0 Epsilon 1.1908594279205509e-14
# Episode 194 Average Reward 333.6855670103093 Best Reward 1588.0 Last Reward 501.0 Epsilon 9.2692058019903e-15
# Episode 195 Average Reward 337.10769230769233 Best Reward 1588.0 Last Reward 1001.0 Epsilon 5.6185438852331495e-15
# Episode 196 Average Reward 338.46938775510205 Best Reward 1588.0 Last Reward 604.0 Epsilon 4.153689643616764e-15
# Episode 197 Average Reward 340.9137055837563 Best Reward 1588.0 Last Reward 820.0 Epsilon 2.756314540035847e-15
# Episode 198 Average Reward 342.3939393939394 Best Reward 1588.0 Last Reward 634.0 Epsilon 2.007349508504391e-15
# Episode 199 Average Reward 344.24120603015075 Best Reward 1588.0 Last Reward 710.0 Epsilon 1.407375214853827e-15
# Episode 200 Average Reward 347.19 Best Reward 1588.0 Last Reward 934.0 Epsilon 8.82152470271174e-16
# Episode 201 Average Reward 348.39800995024876 Best Reward 1588.0 Last Reward 590.0 Epsilon 6.567419264226899e-16
# Episode 202 Average Reward 352.3811881188119 Best Reward 1588.0 Last Reward 1153.0 Epsilon 3.689447715353056e-16
# Episode 203 Average Reward 354.8965517241379 Best Reward 1588.0 Last Reward 863.0 Epsilon 2.396163376805083e-16
# Episode 204 Average Reward 356.4656862745098 Best Reward 1588.0 Last Reward 675.0 Epsilon 1.7096428039355828e-16
# Episode 205 Average Reward 357.64878048780486 Best Reward 1588.0 Last Reward 599.0 Epsilon 1.267073058340746e-16
# Episode 206 Average Reward 361.1747572815534 Best Reward 1588.0 Last Reward 1084.0 Epsilon 7.368094392031796e-17
# Episode 207 Average Reward 363.6473429951691 Best Reward 1588.0 Last Reward 873.0 Epsilon 4.7614390718054615e-17
# Episode 208 Average Reward 365.6923076923077 Best Reward 1588.0 Last Reward 789.0 Epsilon 3.2089740988104754e-17
# Episode 209 Average Reward 368.86602870813397 Best Reward 1588.0 Last Reward 1029.0 Epsilon 1.9180760431530344e-17
# Episode 210 Average Reward 372.9095238095238 Best Reward 1588.0 Last Reward 1218.0 Epsilon 1.043072121766909e-17
# Episode 211 Average Reward 376.38862559241704 Best Reward 1588.0 Last Reward 1107.0 Epsilon 5.996146385886877e-18
# Episode 212 Average Reward 378.5801886792453 Best Reward 1588.0 Last Reward 841.0 Epsilon 3.937365456583317e-18
# Episode 213 Average Reward 381.7511737089202 Best Reward 1588.0 Last Reward 1054.0 Epsilon 2.3242096363196263e-18
# Episode 214 Average Reward 383.49532710280374 Best Reward 1588.0 Last Reward 755.0 Epsilon 1.5932654198602224e-18
# Episode 215 Average Reward 385.5581395348837 Best Reward 1588.0 Last Reward 827.0 Epsilon 1.0535677102782778e-18
# Episode 216 Average Reward 385.8009259259259 Best Reward 1588.0 Last Reward 438.0 Epsilon 8.463074711576998e-19
# Episode 217 Average Reward 388.38709677419354 Best Reward 1588.0 Last Reward 947.0 Epsilon 5.270336087300292e-19
# Episode 218 Average Reward 393.23394495412845 Best Reward 1588.0 Last Reward 1445.0 Epsilon 2.5584802988768095e-19
# Episode 219 Average Reward 397.0365296803653 Best Reward 1588.0 Last Reward 1226.0 Epsilon 1.385775828611413e-19
# Episode 220 Average Reward 398.8954545454545 Best Reward 1588.0 Last Reward 806.0 Epsilon 9.260374191269204e-20
# Episode 221 Average Reward 400.5656108597285 Best Reward 1588.0 Last Reward 768.0 Epsilon 6.306926193221571e-20
# Episode 222 Average Reward 403.036036036036 Best Reward 1588.0 Last Reward 949.0 Epsilon 3.9236791044559404e-20
# Episode 223 Average Reward 405.39910313901345 Best Reward 1588.0 Last Reward 930.0 Epsilon 2.4643139983144607e-20
# Episode 224 Average Reward 406.67410714285717 Best Reward 1588.0 Last Reward 691.0 Epsilon 1.7442541936938615e-20
# Episode 225 Average Reward 408.08444444444444 Best Reward 1588.0 Last Reward 724.0 Epsilon 1.2143834967725253e-20
# Episode 226 Average Reward 411.03097345132744 Best Reward 1588.0 Last Reward 1074.0 Epsilon 7.09710770941131e-21
# Episode 227 Average Reward 413.8193832599119 Best Reward 1588.0 Last Reward 1044.0 Epsilon 4.2103963689792164e-21
# Episode 228 Average Reward 418.0701754385965 Best Reward 1588.0 Last Reward 1383.0 Epsilon 2.108304057371174e-21
# Episode 229 Average Reward 419.3711790393013 Best Reward 1588.0 Last Reward 716.0 Epsilon 1.4737266520106602e-21
# Episode 230 Average Reward 421.0913043478261 Best Reward 1588.0 Last Reward 815.0 Epsilon 9.803873024609171e-22
# Episode 231 Average Reward 423.64935064935065 Best Reward 1588.0 Last Reward 1012.0 Epsilon 5.910030380996345e-22
# Episode 232 Average Reward 430.54741379310343 Best Reward 2024.0 Last Reward 2024.0 Epsilon 2.147700828068095e-22
# Episode 233 Average Reward 435.44635193133047 Best Reward 2024.0 Last Reward 1572.0 Epsilon 9.78437196278737e-23
# Episode 234 Average Reward 438.9230769230769 Best Reward 2024.0 Last Reward 1249.0 Epsilon 5.238997891988199e-23
# Episode 235 Average Reward 440.6936170212766 Best Reward 2024.0 Last Reward 855.0 Epsilon 3.416181228704691e-23
# Episode 236 Average Reward 441.58898305084745 Best Reward 2024.0 Last Reward 652.0 Epsilon 2.4656163091547806e-23
# Episode 237 Average Reward 443.5021097046413 Best Reward 2024.0 Last Reward 895.0 Epsilon 1.5759052797312477e-23
# Episode 238 Average Reward 445.0504201680672 Best Reward 2024.0 Last Reward 812.0 Epsilon 1.0499351014224737e-23
# Episode 239 Average Reward 447.69874476987445 Best Reward 2024.0 Last Reward 1078.0 Epsilon 6.123774483904314e-24
# Episode 240 Average Reward 448.3333333333333 Best Reward 2024.0 Last Reward 600.0 Epsilon 4.536263371053222e-24
# Episode 241 Average Reward 450.76763485477176 Best Reward 2024.0 Last Reward 1035.0 Epsilon 2.70330259536744e-24
# Episode 242 Average Reward 453.2107438016529 Best Reward 2024.0 Last Reward 1042.0 Epsilon 1.6053533940715848e-24
# Episode 243 Average Reward 455.1152263374486 Best Reward 2024.0 Last Reward 916.0 Epsilon 1.0153459353040428e-24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 147
#     145 if i % 100 == 0:
#     146     env.render()
# --> 147 action = agent.choose_action(state)
#     148 state_, reward, done, trunc, info = env.step(action)
#     149 state_ = np.reshape(state_, [1, observation_space])
#
# Cell In[9], line 101, in DQN_Solver.choose_action(self, observation)
#      98     return env.action_space.sample()
#     100 state = torch.tensor(observation).float().detach()
# --> 101 state = state.to(DEVICE)
#     102 state = state.unsqueeze(0)
#     103 q_values = self.network(state)
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Storing and Loading the Trained Agent

# %%
# torch.save(agent.network.state_dict(), "supermodel.pt")
model = Network()
model.load_state_dict(torch.load("supermodel.pt"))
model.eval()
trained_agent = DQN_Solver(model, 0)
try:
    for i in range(1, 5):
        state = env.reset()[0]
        state = np.reshape(state, [1, observation_space])
        score = 0
        
        while True:
            if i % 100 == 0:
                env.render()
            action = trained_agent.choose_action(state)
            state_, reward, done, trunc, info = env.step(action)
            state_ = np.reshape(state_, [1, observation_space])
            trained_agent.memory.add(state, action, reward, state_, done)
            state = state_
            score += reward

            if done or score > 50000:
                if score > best_reward:
                    best_reward = score
                average_reward += score 
                print("Episode {} Average Reward {} Best Reward {} Last Reward {} Epsilon {}".format(i, average_reward/i, best_reward, score, trained_agent.returning_epsilon()))
                break
                
            episode_number.append(i)
            average_reward_number.append(average_reward/i)

    plt.plot(episode_number, average_reward_number)
    plt.show()
    env.close()
except KeyboardInterrupt as e:
    print("Episode: {} Reward: {} Epsilon: {}".format(i, score, trained_agent.returning_epsilon()))
    env.close()
# Out:
# C:\Users\jfrie\AppData\Local\Temp\ipykernel_26564\1154776953.py:65: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   self.dones = np.zeros(MEM_SIZE, dtype=np.bool)
# Episode 1 Average Reward 359875.0 Best Reward 65325.0 Last Reward 768.0 Epsilon 0
# Episode 2 Average Reward 180293.0 Best Reward 65325.0 Last Reward 711.0 Epsilon 0
# Episode 3 Average Reward 120447.66666666667 Best Reward 65325.0 Last Reward 757.0 Epsilon 0
# Episode 4 Average Reward 90502.5 Best Reward 65325.0 Last Reward 667.0 Epsilon 0
